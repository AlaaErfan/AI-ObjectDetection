# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pwd
# Out:
# '/content'

# %%
import keras
from keras.datasets import fashion_mnist

import numpy as np
from PIL import Image, ImageOps
import os

# %%
# to change every_folder with label  

code = {'Tshirt':0 ,'Trouser':1,'Pullover':2,'Dress':3,'Coat':4,'Sandal':5,'Shirt':6,'Sneaker':7,'Bag':8,'Ankle boot':9}
#######################
def getcode(n) : 
    for x , y in code.items() : 
        if n == y : 
            return x

# %%
def save_image(filename, data_array):
    im = Image.fromarray(data_array.astype('uint8'))
    im_invert = ImageOps.invert(im)
    im_invert.save(filename)

# Load Fashion-MNIST Data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

DIR_NAME = "/content/drive/MyDrive/content/data2/train/Tshirt"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Trouser"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Dress"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Coat"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Sandal"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Shirt"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Sneaker"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Ankle boot"    
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Bag"  
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/train/Pullover"  
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)

# Save Images
i = 0
for li in [x_train]:
    print("[---------------------------------------------------------------]")
    for x in li:
        name = getcode(y_train[i])
        if name == "Tshirt" :
            filename = "/content/drive/MyDrive/content/data2/train/Tshirt/{0}.jpg".format(i)
        elif name == "Trouser" :
            filename = "/content/drive/MyDrive/content/data2/train/Trouser/{0}.jpg".format(i)
        elif name == "Dress" :
            filename = "/content/drive/MyDrive/content/data2/train/Dress/{0}.jpg".format(i)
        elif name == "Coat" :
            filename = "/content/drive/MyDrive/content/data2/train/Coat/{0}.jpg".format(i)
        elif name == "Sandal" :
            filename = "/content/drive/MyDrive/content/data2/train/Sandal/{0}.jpg".format(i)
        elif name == "Shirt" :
            filename = "/content/drive/MyDrive/content/data2/train/Shirt/{0}.jpg".format(i)
        elif name == "Sneaker" :
            filename = "/content/drive/MyDrive/content/data2/train/Sneaker/{0}.jpg".format(i)
        elif name == "Bag" :
            filename = "/content/drive/MyDrive/content/data2/train/Bag/{0}.jpg".format(i)
        elif name == "Ankle boot" :
            filename = "/content/drive/MyDrive/content/data2/train/Ankle boot/{0}.jpg".format(i)
        elif name == "Pullover" :
            filename = "/content/drive/MyDrive/content/data2/train/Pullover/{0}.jpg".format(i)
        print(filename)
        save_image(filename, x)
        i += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/content/data2/train/Tshirt/55000.jpg
# /content/drive/MyDrive/content/data2/train/Bag/55001.jpg
# /content/drive/MyDrive/content/data2/train/Tshirt/55002.jpg
# /content/drive/MyDrive/content/data2/train/Shirt/55003.jpg
# /content/drive/MyDrive/content/data2/train/Sandal/55004.jpg
# /content/drive/MyDrive/content/data2/train/Bag/55005.jpg
# /content/drive/MyDrive/content/data2/train/Tshirt/55006.jpg
# /content/drive/MyDrive/content/data2/train/Coat/55007.jpg
# /content/drive/MyDrive/content/data2/train/Sneaker/55008.jpg
# /content/drive/MyDrive/content/data2/train/Bag/55009.jpg
# /content/drive/MyDrive/content/data2/train/Shirt/55010.jpg
# /content/drive/MyDrive/content/data2/train/Sneaker/55011.jpg
# /content/drive/MyDrive/content/data2/train/Tshirt/55012.jpg
# /content/drive/MyDrive/content/data2/train/Ankle boot/55013.jpg
# /content/drive/MyDrive/content/data2/train/Sneaker/55014.jpg
# ...

# %%
def save_image(filename, data_array):
    im = Image.fromarray(data_array.astype('uint8'))
    im_invert = ImageOps.invert(im)
    im_invert.save(filename)

# Load Fashion-MNIST Data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

DIR_NAME = "/content/drive/MyDrive/content/data2/test/Tshirt"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Trouser"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Dress"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Coat"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Sandal"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Shirt"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Sneaker"
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Ankle boot"    
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Bag"  
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)
DIR_NAME = "/content/drive/MyDrive/content/data2/test/Pullover"  
if os.path.exists(DIR_NAME) == False:
    os.mkdir(DIR_NAME)

# Save Images
i = 0
for li in [x_train]:
    print("[---------------------------------------------------------------]")
    for x in li:
        name = getcode(y_train[i])
        if name == "Tshirt" :
            filename = "/content/drive/MyDrive/content/data2/test/Tshirt/{0}.jpg".format(i)
        elif name == "Trouser" :
            filename = "/content/drive/MyDrive/content/data2/test/Trouser/{0}.jpg".format(i)
        elif name == "Dress" :
            filename = "/content/drive/MyDrive/content/data2/test/Dress/{0}.jpg".format(i)
        elif name == "Coat" :
            filename = "/content/drive/MyDrive/content/data2/test/Coat/{0}.jpg".format(i)
        elif name == "Sandal" :
            filename = "/content/drive/MyDrive/content/data2/test/Sandal/{0}.jpg".format(i)
        elif name == "Shirt" :
            filename = "/content/drive/MyDrive/content/data2/test/Shirt/{0}.jpg".format(i)
        elif name == "Sneaker" :
            filename = "/content/drive/MyDrive/content/data2/test/Sneaker/{0}.jpg".format(i)
        elif name == "Bag" :
            filename = "/content/drive/MyDrive/content/data2/test/Bag/{0}.jpg".format(i)
        elif name == "Ankle boot" :
            filename = "/content/drive/MyDrive/content/data2/test/Ankle boot/{0}.jpg".format(i)
        elif name == "Pullover" :
            filename = "/content/drive/MyDrive/content/data2/test/Pullover/{0}.jpg".format(i)
        print(filename)
        save_image(filename, x)
        i += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/content/data2/test/Tshirt/55000.jpg
# /content/drive/MyDrive/content/data2/test/Bag/55001.jpg
# /content/drive/MyDrive/content/data2/test/Tshirt/55002.jpg
# /content/drive/MyDrive/content/data2/test/Shirt/55003.jpg
# /content/drive/MyDrive/content/data2/test/Sandal/55004.jpg
# /content/drive/MyDrive/content/data2/test/Bag/55005.jpg
# /content/drive/MyDrive/content/data2/test/Tshirt/55006.jpg
# /content/drive/MyDrive/content/data2/test/Coat/55007.jpg
# /content/drive/MyDrive/content/data2/test/Sneaker/55008.jpg
# /content/drive/MyDrive/content/data2/test/Bag/55009.jpg
# /content/drive/MyDrive/content/data2/test/Shirt/55010.jpg
# /content/drive/MyDrive/content/data2/test/Sneaker/55011.jpg
# /content/drive/MyDrive/content/data2/test/Tshirt/55012.jpg
# /content/drive/MyDrive/content/data2/test/Ankle boot/55013.jpg
# /content/drive/MyDrive/content/data2/test/Sneaker/55014.jpg
# ...

# %%
from keras import models
c=models.load_model('/content/ClothesFinal3.h5')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import seaborn as sns
sns.set(style="whitegrid")
import os
import glob as gb
import cv2
from scipy import misc
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import scipy.misc
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from skimage import color
from skimage import io

# %%
trainpath = '/content/drive/MyDrive/content/data2/'
testpath =  '/content/drive/MyDrive/content/data2/'

# %%
# Reading files [ training_dataset ] 

for folder in  os.listdir(trainpath + 'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    print(f'For training data , found {len(files)} in folder {folder}')
# Out:
# For training data , found 6000 in folder Coat
# For training data , found 6000 in folder Tshirt
# For training data , found 6000 in folder Shirt
# For training data , found 6000 in folder Trouser
# For training data , found 6000 in folder Sneaker
# For training data , found 6000 in folder Bag
# For training data , found 6000 in folder Dress
# For training data , found 6000 in folder Pullover
# For training data , found 6000 in folder Ankle boot
# For training data , found 6000 in folder Sandal

# %%
# Reading files [ test_dataset ]

for folder in  os.listdir(testpath +'test') : 
    files = gb.glob(pathname= str( testpath +'test//' + folder + '/*.jpg'))
    print(f'For testing data , found {len(files)} in folder {folder}')
# Out:
# For testing data , found 6000 in folder Tshirt
# For testing data , found 6000 in folder Shirt
# For testing data , found 6000 in folder Trouser
# For testing data , found 6000 in folder Dress
# For testing data , found 6000 in folder Bag
# For testing data , found 6000 in folder Sneaker
# For testing data , found 6000 in folder Coat
# For testing data , found 6000 in folder Pullover
# For testing data , found 6000 in folder Ankle boot
# For testing data , found 6000 in folder Sandal

# %%
# to change every_folder with label  

code = {'Tshirt':0 ,'Trouser':1,'Pullover':2,'Dress':3,'Coat':4,'Sandal':5,'Shirt':6,'Sneaker':7,'Bag':8,'Ankle boot':9}
#######################
def getcode(n) : 
    for x , y in code.items() : 
        if n == y : 
            return x

# %%
# to get more info about train_data  ex:[size of each pic , color , num of each size] 
size = []
for folder in  os.listdir(trainpath +'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()
# Out:
# (28, 28)    60000
# dtype: int64

# %%
# to resize images_train to one equalied size      
X_train = []
y_train = []

for folder in  os.listdir(trainpath +'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    for file in files: 
        image = cv2.imread(file)
        imgGray = color.rgb2gray( image)
        X_train.append(list(imgGray))
        y_train.append(code[folder])

# %%
# to resize images_test to one equalied size 

X_test = []
y_test = []
for folder in  os.listdir(testpath +'test') : 
    files = gb.glob(pathname= str(testpath + 'test//' + folder + '/*.jpg'))
    for file in files: 
        image = cv2.imread(file)
        imgGray = color.rgb2gray( image)
        X_test.append(list(imgGray))
        y_test.append(code[folder])

# %%
################# preprocessing images to arrays ####################
X_train = np.array(X_train)
X_test = np.array(X_test)
#X_pred_array = np.array(X_pred)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
y_pred = c.predict(X_test)
for i in  range(len(y_pred)):
    print([getcode(np.argmax(y_pred[i])),getcode(y_test[i])])
# Out:
# Streaming output truncated to the last 5000 lines.
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Ankle boot', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ['Sandal', 'Sandal']
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print(np.argmax(y_pred[0]))
predicition=[]
for i in range(len(y_pred)):
  predicition.append(np.argmax(y_pred[i]))
cm = confusion_matrix(y_test, predicition)
print(cm)
accuracy_score(y_test, predicition)
# Out:
# 0
# [[5268    4  120  274   14    2  250    0   68    0]
#  [  20 5775   38  149    9    1    5    0    3    0]
#  [  92    0 5024   73  498    1  268    1   43    0]
#  [ 164   16   64 5502  176    1   62    1   14    0]
#  [   8    3  501  217 4764    1  477    1   28    0]
#  [   3    0    0    2    0 5816    2   98   48   31]
#  [1045    6  735  224  349    0 3533    0  107    1]
#  [   0    0    0    0    0  377    0 5479   25  119]
#  [  17    0   26   22   25    5   22   10 5871    2]
#  [   1    0    1    1    0  185    0  241   10 5561]]
# 0.87655

# %%
from sklearn.metrics import roc_curve
from sklearn import metrics
from itertools import cycle
y_pred= c.predict(X_test)
predicition=[]
for i in range(len(y_pred)):
  predicition.append(np.argmax(y_pred[i]))

fpr = dict()
tpr = dict()
roc_auc = dict()
lw=2
for i in range(10):
    fpr[i], tpr[i], _ = roc_curve(y_test, predicition,pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','orange','purple','black','yellow','maroon','brown','gray'])
for i, color in zip(range(10), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class data')
# plt.legend(loc="lower right")
plt.show()
# Out:
# 1875/1875 [==============================] - 5s 3ms/step
